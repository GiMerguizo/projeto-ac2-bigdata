# %% [markdown]
# # Acidentes no Espaço Aéreo Brasileiro (Cenipa)
# Projeto AC2 - Big Data

# %% [markdown]
# ## Configuração do Dataset

# %%
# Importando bibliotecas necessárias
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, isnan, when
from pyspark.ml.feature import VectorAssembler, StringIndexer, OneHotEncoder
from pyspark.ml.classification import DecisionTreeClassifier, LogisticRegression, MultilayerPerceptronClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

spark = SparkSession.builder \
    .appName("Cenipa_BigData_Classification") \
    .getOrCreate()

# %%
dataframe = spark.read.csv("./assets/data/Cenipa.csv", header=True, inferSchema=True, sep=";")

num_linhas = dataframe.count()
print(f"Número de linhas no DataFrame: {num_linhas}")
# Out:
# Número de linhas no DataFrame: 6114

# %% [markdown]
# ## Análise de Dados

# %%
# Visualizando o esquema dos dados
dataframe.printSchema()
# Out:
# root
#  |-- Codigo da Ocorrencia: integer (nullable = true)
#  |-- Classificacao da Ocorrencia : string (nullable = true)
#  |-- Data e Hora da Ocorrencia: string (nullable = true)
#  |-- Latitude da Ocorrencia: string (nullable = true)
#  |-- Longitude da Ocorrencia: string (nullable = true)
#  |-- Cidade da Ocorrencia: string (nullable = true)
#  |-- UF da Ocorrencia: string (nullable = true)
#  |-- Pais da Ocorrencia: string (nullable = true)
#  |-- Aerodromo da Ocorrencia: string (nullable = true)
#  |-- Investigacao da Aeronave foi Liberada: string (nullable = true)
#  |-- Status da Investigacao: string (nullable = true)
#  |-- Numero do Relatorio de Divulgacao: string (nullable = true)
#  |-- Relatorio de  Divulgacao foi Publicado?: string (nullable = true)
#  |-- Dia da Divulgacao da Publicacao: string (nullable = true)
#  |-- Total de Recomendacoes: integer (nullable = true)
#  |-- Total de Aeronaves Envolvidas: integer (nullable = true)
#  |-- Ocorrencia na Saida da Pista?: string (nullable = true)
#  |-- Tipo de Ocorrencia: string (nullable = true)
#  |-- Tipo de Categoria da Ocorrencia: string (nullable = true)
#  |-- Taxonomia do Tipo de Icao: string (nullable = true)
#  |-- Matricula da Aeronave: string (nullable = true)
#  |-- Categoria do Operador de Aeronave: string (nullable = true)
#  |-- Tipo de Aeronave: string (nullable = true)
#  |-- Fabricante da Aeronave: string (nullable = true)
#  |-- Modelo de Aeronave: string (nullable = true)
#  |-- Tipo de Aeronave Icao: string (nullable = true)
#  |-- Aeronave Motor Tipo: string (nullable = true)
#  |-- Aeronave Motor Quantidade: string (nullable = true)
#  |-- Aeronave PMD: integer (nullable = true)
#  |-- Categoria PMD Aeronave: integer (nullable = true)
#  |-- Quantidade de Assentos na Aeronave: integer (nullable = true)
#  |-- Ano de Fabricacao da Aeronave: integer (nullable = true)
#  |-- Pais Fabricante da Aeronave: string (nullable = true)
#  |-- Pais de Registro da Aeronave: string (nullable = true)
#  |-- Registro da Categoria da Aeronave: string (nullable = true)
#  |-- Registro Segmento da Aeronave: string (nullable = true)
#  |-- Voo de Origem do Acidente: string (nullable = true)
#  |-- Voo Destino do Acidente: string (nullable = true)
#  |-- Fase de Operacao da Aeronave: string (nullable = true)
#  |-- Tipo de Operacao da Aeronave: string (nullable = true)
#  |-- Nivel de Dano da Aeronave: string (nullable = true)
#  |-- Total de Fatalidades no Acidente: integer (nullable = true)
#  |-- Fator do Acidente: string (nullable = true)
#  |-- Aspecto do Fator da Ocorrencia: string (nullable = true)
#  |-- Fator Condicionante: string (nullable = true)
#  |-- Area do Fator: string (nullable = true)
#  |-- Numero da Recomendacao: string (nullable = true)
#  |-- Dia da Assinatura de Recomendacao: string (nullable = true)
#  |-- Dia do Encaminhamento da Recomendacao: string (nullable = true)
#  |-- Conteudo da Recomendacao: string (nullable = true)
#  |-- Status da Recomendacao: string (nullable = true)
#  |-- Orgao de Recomendacao: string (nullable = true)

# %%
dataframe.show(5)
# Out:
# +--------------------+----------------------------+-------------------------+----------------------+-----------------------+--------------------+----------------+------------------+-----------------------+-------------------------------------+----------------------+---------------------------------+---------------------------------------+-------------------------------+----------------------+-----------------------------+-----------------------------+--------------------+-------------------------------+-------------------------+---------------------+---------------------------------+----------------+----------------------+------------------+---------------------+-------------------+-------------------------+------------+----------------------+----------------------------------+-----------------------------+---------------------------+----------------------------+---------------------------------+-----------------------------+-------------------------+-----------------------+----------------------------+----------------------------+-------------------------+--------------------------------+--------------------+------------------------------+--------------------+-----------------+----------------------+---------------------------------+-------------------------------------+------------------------+----------------------+---------------------+
# |Codigo da Ocorrencia|Classificacao da Ocorrencia |Data e Hora da Ocorrencia|Latitude da Ocorrencia|Longitude da Ocorrencia|Cidade da Ocorrencia|UF da Ocorrencia|Pais da Ocorrencia|Aerodromo da Ocorrencia|Investigacao da Aeronave foi Liberada|Status da Investigacao|Numero do Relatorio de Divulgacao|Relatorio de  Divulgacao foi Publicado?|Dia da Divulgacao da Publicacao|Total de Recomendacoes|Total de Aeronaves Envolvidas|Ocorrencia na Saida da Pista?|  Tipo de Ocorrencia|Tipo de Categoria da Ocorrencia|Taxonomia do Tipo de Icao|Matricula da Aeronave|Categoria do Operador de Aeronave|Tipo de Aeronave|Fabricante da Aeronave|Modelo de Aeronave|Tipo de Aeronave Icao|Aeronave Motor Tipo|Aeronave Motor Quantidade|Aeronave PMD|Categoria PMD Aeronave|Quantidade de Assentos na Aeronave|Ano de Fabricacao da Aeronave|Pais Fabricante da Aeronave|Pais de Registro da Aeronave|Registro da Categoria da Aeronave|Registro Segmento da Aeronave|Voo de Origem do Acidente|Voo Destino do Acidente|Fase de Operacao da Aeronave|Tipo de Operacao da Aeronave|Nivel de Dano da Aeronave|Total de Fatalidades no Acidente|   Fator do Acidente|Aspecto do Fator da Ocorrencia| Fator Condicionante|    Area do Fator|Numero da Recomendacao|Dia da Assinatura de Recomendacao|Dia do Encaminhamento da Recomendacao|Conteudo da Recomendacao|Status da Recomendacao|Orgao de Recomendacao|
# +--------------------+----------------------------+-------------------------+----------------------+-----------------------+--------------------+----------------+------------------+-----------------------+-------------------------------------+----------------------+---------------------------------+---------------------------------------+-------------------------------+----------------------+-----------------------------+-----------------------------+--------------------+-------------------------------+-------------------------+---------------------+---------------------------------+----------------+----------------------+------------------+---------------------+-------------------+-------------------------+------------+----------------------+----------------------------------+-----------------------------+---------------------------+----------------------------+---------------------------------+-----------------------------+-------------------------+-----------------------+----------------------------+----------------------------+-------------------------+--------------------------------+--------------------+------------------------------+--------------------+-----------------+----------------------+---------------------------------+-------------------------------------+------------------------+----------------------+---------------------+
# |               39115|                    ACIDENTE|         07/02/2010 17:40|             -1,34E+11|              -4,46E+11|          CORRENTINA|              BA|            BRASIL|                   SNTY|                                  SIM|            FINALIZADA|                A-031/CENIPA/2011|                                    SIM|                     21/07/2011|                     2|                            1|                          NÃO|           PANE SECA|           COMBUSTÍVEL | PAN...|                     FUEL|                PTNQX|                              ***|           AVIÃO|  NEIVA INDUSTRIA A...|          EMB-711A|                 P28R|             PISTÃO|                MONOMOTOR|        1202|                  1202|                                 4|                         1979|                     BRASIL|                      BRASIL|                            AVIÃO|                   PARTICULAR|     BRIGADEIRO ARARIP...|             CORRENTINA|                   DECOLAGEM|                     PRIVADA|              SUBSTANCIAL|                               0|APLICAÇÃO DE COMA...|          DESEMPENHO DO SER...|OPERAÇÃO DA AERONAVE|FATOR OPERACIONAL|              095/2011|                       21/07/2011|                     01/08/2011 00:00|    Revisar os requis...|          NÃO CUMPRIDA|                 ANAC|
# |               39156|             INCIDENTE GRAVE|         10/01/2010 23:15|             -1,52E+11|              -5,94E+11|            CASCAVEL|              PR|            BRASIL|                   SBCA|                                  SIM|            FINALIZADA|                I-004/CENIPA/2011|                                    SIM|                     30/06/2011|                     2|                            1|                          NÃO|         FOGO EM VOO|           FOGO/FUMAÇA (SEM ...|                     F-NI|                PPPTO|                              ***|           AVIÃO|  AEROSPATIALE AND ...|       ATR-72-212A|                 AT72|         TURBOÉLICE|                  BIMOTOR|       22500|                 22500|                                73|                         2008|                     BRASIL|                      BRASIL|                            AVIÃO|                      REGULAR|              AFONSO PENA|   ADALBERTO MENDES ...|            ARREMETIDA NO AR|                     REGULAR|                     LEVE|                               0|MANUTENÇÃO DA AER...|          DESEMPENHO DO SER...|MANUTENÇÃO DA AER...|FATOR OPERACIONAL|              063/2011|                       30/06/2011|                     01/08/2011 00:00|    Divulgar este Rel...|              CUMPRIDA|                 ANAC|
# |               39235|                    ACIDENTE|         06/02/2010 17:20|             -1,81E+11|              -5,01E+11|           ITUMBIARA|              GO|            BRASIL|                   ****|                                  SIM|            FINALIZADA|                A-067/CENIPA/2011|                                    SIM|                     29/08/2011|                     3|                            1|                          NÃO|PERDA DE CONTROLE...|           PERDA DE CONTROLE...|                    LOC-I|                PTWKN|                              ***|           AVIÃO|       CESSNA AIRCRAFT|             A188B|                 C188|             PISTÃO|                MONOMOTOR|        1497|                  1497|                                 1|                         1976|                     BRASIL|                      BRASIL|                            AVIÃO|                     AGRÍCOLA|        FORA DE AERODROMO|      FORA DE AERODROMO|                   DECOLAGEM|                    AGRÍCOLA|                DESTRUÍDA|                               1| PLANEJAMENTO DE VOO|          DESEMPENHO DO SER...|OPERAÇÃO DA AERONAVE|FATOR OPERACIONAL|              205/2011|                       29/08/2011|                     29/09/2011 00:00|    Realizar uma vist...|              CUMPRIDA|                 ANAC|
# |               39275|                    ACIDENTE|         10/02/2010 09:03|             -2,36E+11|              -4,67E+11|           SÃO PAULO|              SP|            BRASIL|                   ****|                                  SIM|            FINALIZADA|                A-009/CENIPA/2014|                                    SIM|                     22/04/2016|                     3|                            1|                          NÃO|FALHA OU MAU FUNC...|           FALHA OU MAU FUNC...|                   SCF-NP|                PTYRE|                              ***|     HELICÓPTERO|     EUROCOPTER FRANCE|         AS 350 BA|                  ***|          TURBOEIXO|                MONOMOTOR|        2100|                  2100|                                 6|                         1994|                     BRASIL|                      BRASIL|                      HELICÓPTERO|                   PARTICULAR|           CAMPO DE MARTE|         CAMPO DE MARTE|                    CRUZEIRO|                     PRIVADA|                DESTRUÍDA|                               1|APLICAÇÃO DE COMA...|          DESEMPENHO DO SER...|OPERAÇÃO DA AERONAVE|FATOR OPERACIONAL|  A-009/CENIPA/2014...|                       22/04/2016|                     17/05/2016 00:00|    Avaliar a necessi...|          NÃO CUMPRIDA|                 ANAC|
# |               39316|                    ACIDENTE|         04/02/2010 17:55|             -2,72E+11|              -4,98E+11|        RIO DO OESTE|              SC|            BRASIL|                   ****|                                  SIM|            FINALIZADA|                A-011/CENIPA/2011|                                    SIM|                     18/05/2011|                     2|                            1|                          NÃO|POUSO ANTES DA PISTA|           POUSO AQUÉM/ALÉM ...|                     USOS|                PPGMH|                              ***|           AVIÃO|            AERO BOERO|            AB-115|                 AB11|             PISTÃO|                MONOMOTOR|         770|                   770|                                 2|                         1992|                     BRASIL|                      BRASIL|                            AVIÃO|                    INSTRUÇÃO|                 BLUMENAU|         RANCHO SUMIDOR|                       POUSO|                   INSTRUÇÃO|              SUBSTANCIAL|                               0|CONDIÇÕES METEORO...|          ELEMENTOS RELACIO...|                 ***|FATOR OPERACIONAL|              034/2011|                       18/05/2011|                     27/05/2011 00:00|    Realizar uma audi...|              CUMPRIDA|                 ANAC|
# +--------------------+----------------------------+-------------------------+----------------------+-----------------------+--------------------+----------------+------------------+-----------------------+-------------------------------------+----------------------+---------------------------------+---------------------------------------+-------------------------------+----------------------+-----------------------------+-----------------------------+--------------------+-------------------------------+-------------------------+---------------------+---------------------------------+----------------+----------------------+------------------+---------------------+-------------------+-------------------------+------------+----------------------+----------------------------------+-----------------------------+---------------------------+----------------------------+---------------------------------+-----------------------------+-------------------------+-----------------------+----------------------------+----------------------------+-------------------------+--------------------------------+--------------------+------------------------------+--------------------+-----------------+----------------------+---------------------------------+-------------------------------------+------------------------+----------------------+---------------------+
# only showing top 5 rows

# %%
# Verificando a distribuição da classe alvo "Classificacao da Ocorrencia"
print("Distribuição da classe alvo (Classificacao da Ocorrencia):")
distribuicao_classes = dataframe.groupBy("Classificacao da Ocorrencia ").count().orderBy(col("count").desc())
distribuicao_classes.show()
# Out:
# Distribuição da classe alvo (Classificacao da Ocorrencia):
# +----------------------------+-----+
# |Classificacao da Ocorrencia |count|
# +----------------------------+-----+
# |                   INCIDENTE| 3393|
# |                    ACIDENTE| 1930|
# |             INCIDENTE GRAVE|  791|
# +----------------------------+-----+

# %% [markdown]
# ## Limpando o Dataset

# %%
# Tratando valores nulos
# dataframe = dataframe.dropna()

num_linhas = dataframe.count()
print(f"Número de linhas no DataFrame: {num_linhas}")
# Out:
# Número de linhas no DataFrame: 6114

# %%
dataframe.printSchema()
# Out:
# root
#  |-- Codigo da Ocorrencia: integer (nullable = true)
#  |-- Classificacao da Ocorrencia : string (nullable = true)
#  |-- Data e Hora da Ocorrencia: string (nullable = true)
#  |-- Latitude da Ocorrencia: string (nullable = true)
#  |-- Longitude da Ocorrencia: string (nullable = true)
#  |-- Cidade da Ocorrencia: string (nullable = true)
#  |-- UF da Ocorrencia: string (nullable = true)
#  |-- Pais da Ocorrencia: string (nullable = true)
#  |-- Aerodromo da Ocorrencia: string (nullable = true)
#  |-- Investigacao da Aeronave foi Liberada: string (nullable = true)
#  |-- Status da Investigacao: string (nullable = true)
#  |-- Numero do Relatorio de Divulgacao: string (nullable = true)
#  |-- Relatorio de  Divulgacao foi Publicado?: string (nullable = true)
#  |-- Dia da Divulgacao da Publicacao: string (nullable = true)
#  |-- Total de Recomendacoes: integer (nullable = true)
#  |-- Total de Aeronaves Envolvidas: integer (nullable = true)
#  |-- Ocorrencia na Saida da Pista?: string (nullable = true)
#  |-- Tipo de Ocorrencia: string (nullable = true)
#  |-- Tipo de Categoria da Ocorrencia: string (nullable = true)
#  |-- Taxonomia do Tipo de Icao: string (nullable = true)
#  |-- Matricula da Aeronave: string (nullable = true)
#  |-- Categoria do Operador de Aeronave: string (nullable = true)
#  |-- Tipo de Aeronave: string (nullable = true)
#  |-- Fabricante da Aeronave: string (nullable = true)
#  |-- Modelo de Aeronave: string (nullable = true)
#  |-- Tipo de Aeronave Icao: string (nullable = true)
#  |-- Aeronave Motor Tipo: string (nullable = true)
#  |-- Aeronave Motor Quantidade: string (nullable = true)
#  |-- Aeronave PMD: integer (nullable = true)
#  |-- Categoria PMD Aeronave: integer (nullable = true)
#  |-- Quantidade de Assentos na Aeronave: integer (nullable = true)
#  |-- Ano de Fabricacao da Aeronave: integer (nullable = true)
#  |-- Pais Fabricante da Aeronave: string (nullable = true)
#  |-- Pais de Registro da Aeronave: string (nullable = true)
#  |-- Registro da Categoria da Aeronave: string (nullable = true)
#  |-- Registro Segmento da Aeronave: string (nullable = true)
#  |-- Voo de Origem do Acidente: string (nullable = true)
#  |-- Voo Destino do Acidente: string (nullable = true)
#  |-- Fase de Operacao da Aeronave: string (nullable = true)
#  |-- Tipo de Operacao da Aeronave: string (nullable = true)
#  |-- Nivel de Dano da Aeronave: string (nullable = true)
#  |-- Total de Fatalidades no Acidente: integer (nullable = true)
#  |-- Fator do Acidente: string (nullable = true)
#  |-- Aspecto do Fator da Ocorrencia: string (nullable = true)
#  |-- Fator Condicionante: string (nullable = true)
#  |-- Area do Fator: string (nullable = true)
#  |-- Numero da Recomendacao: string (nullable = true)
#  |-- Dia da Assinatura de Recomendacao: string (nullable = true)
#  |-- Dia do Encaminhamento da Recomendacao: string (nullable = true)
#  |-- Conteudo da Recomendacao: string (nullable = true)
#  |-- Status da Recomendacao: string (nullable = true)
#  |-- Orgao de Recomendacao: string (nullable = true)

# %% [markdown]
# ## Pré-Processamento

# %%
# 1. Removendo registros nulos na coluna alvo
df_clean = dataframe.dropna(subset=["Classificacao da Ocorrencia "])

# 2. Convertendo a coluna alvo (String) para valores numéricos (Double)
label_indexer = StringIndexer(inputCol="Classificacao da Ocorrencia ", outputCol="label")
df_clean = label_indexer.fit(df_clean).transform(df_clean)

# 3. Tratamento de classes desbalanceadas (Undersampling)
# Calculamos a proporção para igualar todas as classes pela classe minoritária
class_counts = df_clean.groupBy('label').count().collect()
min_count = min([row['count'] for row in class_counts])
fractions = {row['label']: min_count / row['count'] for row in class_counts}

df_balanced = df_clean.sampleBy('label', fractions, seed=42)
print("Distribuição após o balanceamento das classes:")
df_balanced.groupBy("label").count().show()

# 4. Seleção e conversão de features
# No dataset do Cenipa, a maioria das colunas são categóricas.
# Aqui definimos colunas de exemplo relevantes para o modelo. 
# (Você deve adicionar as colunas do seu interesse após avaliar o schema).
categorical_cols = ["Tipo da Ocorrencia", "UF", "Fase de Operacao"]

indexers = [StringIndexer(inputCol=c, outputCol=f"{c}_indexed", handleInvalid="keep") for c in categorical_cols]
encoders = [OneHotEncoder(inputCol=f"{c}_indexed", outputCol=f"{c}_vec") for c in categorical_cols]

# Vetorizando as features preparadas
assembler_inputs = [f"{c}_vec" for c in categorical_cols]
vector_assembler = VectorAssembler(inputCols=assembler_inputs, outputCol="features")

# Criando um pipeline de pré-processamento
pre_process_pipeline = Pipeline(stages=indexers + encoders + [vector_assembler])
df_model_ready = pre_process_pipeline.fit(df_balanced).transform(df_balanced)
# Out:
# Distribuição após o balanceamento das classes:
# +-----+-----+
# |label|count|
# +-----+-----+
# |  0.0|  796|
# |  1.0|  821|
# |  2.0|  791|
# +-----+-----+
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 25
#      22 categorical_cols = ["Tipo da Ocorrencia", "UF", "Fase de Operacao"]
#      24 indexers = [StringIndexer(inputCol=c, outputCol=f"{c}_indexed", handleInvalid="keep") for c in categorical_cols]
# ---> 25 encoders = [OneHotEncoder(inputCol=f"{c}_indexed", outputCol=f"{c}_vec") for c in categorical_cols]
#      27 # Vetorizando as features preparadas
#      28 assembler_inputs = [f"{c}_vec" for c in categorical_cols]
#
# Cell In[36], line 25, in <listcomp>(.0)
#      22 categorical_cols = ["Tipo da Ocorrencia", "UF", "Fase de Operacao"]
#      24 indexers = [StringIndexer(inputCol=c, outputCol=f"{c}_indexed", handleInvalid="keep") for c in categorical_cols]
# ---> 25 encoders = [OneHotEncoder(inputCol=f"{c}_indexed", outputCol=f"{c}_vec") for c in categorical_cols]
#      27 # Vetorizando as features preparadas
#      28 assembler_inputs = [f"{c}_vec" for c in categorical_cols]
#
# NameError: name 'OneHotEncoder' is not defined
